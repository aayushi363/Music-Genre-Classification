# %%
import tensorflow as tf
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
# from google.colab import drive
# drive.mount("/content/drive")

# %%
import json
import numpy as np
from sklearn.model_selection import train_test_split

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten,LSTM,MaxPool2D,BatchNormalization,GRU
from tensorflow.keras.optimizers import Adam,SGD
from tensorflow.keras.regularizers import l1_l2,l2

with open('gtzan_mfcc.json', "r") as file:
    data = json.load(file) #Load MFCC dataset from JSON file

# convert lists to numpy arrays
X = np.array(data["mfcc"]) #Load MFCCs 
y = np.array(data["labels"]) #Load corresponding genre names



X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1,random_state=0) #Splitting data into random training and test sets

# %%
from keras.callbacks import ReduceLROnPlateau
rlrop = ReduceLROnPlateau(monitor='val_accuracy', factor=0.05, patience=5) #Reduce learning rate when a metric has stopped improving

model = Sequential() #Initializing a sequential model

model.add(LSTM(128, input_shape=(X_train.shape[1],X_train.shape[2]), return_sequences=True)) #Add a Long Short-Term Memory layer
model.add(LSTM(128)) #Add a Long Short-Term Memory layer

model.add(Dense(64, activation='relu',kernel_initializer='he_uniform')) #Add a densely connected layer to the neural network
model.add(Dense(64, activation='relu',kernel_initializer='he_uniform')) #Add a densely connected layer to the neural network

model.add(Dense(10, activation = "softmax")) #Add a densely connected output layer to the neural network

# %%
optimiser = Adam(learning_rate=0.0001) #Initializes Adam optimizer for training
model.compile(optimizer=optimiser,loss='sparse_categorical_crossentropy',metrics=['accuracy']) #Configures the model for training

# %%
model.summary() #Prints a string summary of the network
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 130, 128)          72704
#
#  lstm_1 (LSTM)               (None, 128)               131584
#
#  dense (Dense)               (None, 64)                8256
#
#  dense_1 (Dense)             (None, 64)                4160
#
#  dense_2 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 217,354
# Trainable params: 217,354
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), batch_size=32, epochs=80, verbose=2,callbacks=[rlrop]) #Trains the model for a fixed number of epochs
# Out:
# Epoch 1/80
# 282/282 - 10s - loss: 1.8443 - accuracy: 0.3682 - val_loss: 1.5077 - val_accuracy: 0.4640 - lr: 1.0000e-04 - 10s/epoch - 35ms/step
# Epoch 2/80
# 282/282 - 5s - loss: 1.3640 - accuracy: 0.5091 - val_loss: 1.3229 - val_accuracy: 0.5160 - lr: 1.0000e-04 - 5s/epoch - 18ms/step
# Epoch 3/80
# 282/282 - 5s - loss: 1.2013 - accuracy: 0.5714 - val_loss: 1.1955 - val_accuracy: 0.5720 - lr: 1.0000e-04 - 5s/epoch - 18ms/step
# Epoch 4/80
# 282/282 - 6s - loss: 1.0983 - accuracy: 0.6027 - val_loss: 1.1451 - val_accuracy: 0.5820 - lr: 1.0000e-04 - 6s/epoch - 20ms/step
# Epoch 5/80
# 282/282 - 5s - loss: 1.0090 - accuracy: 0.6445 - val_loss: 1.1037 - val_accuracy: 0.6110 - lr: 1.0000e-04 - 5s/epoch - 19ms/step
# Epoch 6/80
# 282/282 - 5s - loss: 0.9419 - accuracy: 0.6639 - val_loss: 1.0261 - val_accuracy: 0.6380 - lr: 1.0000e-04 - 5s/epoch - 18ms/step
# Epoch 7/80
# 282/282 - 5s - loss: 0.8756 - accuracy: 0.6859 - val_loss: 0.9768 - val_accuracy: 0.6410 - lr: 1.0000e-04 - 5s/epoch - 19ms/step
# Epoch 8/80
# 282/282 - 6s - loss: 0.8231 - accuracy: 0.7056 - val_loss: 0.9513 - val_accuracy: 0.6690 - lr: 1.0000e-04 - 6s/epoch - 22ms/step
# Epoch 9/80
# 282/282 - 5s - loss: 0.7637 - accuracy: 0.7417 - val_loss: 0.9376 - val_accuracy: 0.6820 - lr: 1.0000e-04 - 5s/epoch - 19ms/step
# Epoch 10/80
# 282/282 - 5s - loss: 0.7455 - accuracy: 0.7414 - val_loss: 0.9389 - val_accuracy: 0.6810 - lr: 1.0000e-04 - 5s/epoch - 19ms/step
# Epoch 11/80
# 282/282 - 5s - loss: 0.6917 - accuracy: 0.7619 - val_loss: 0.8582 - val_accuracy: 0.6890 - lr: 1.0000e-04 - 5s/epoch - 19ms/step
# Epoch 12/80
# 282/282 - 6s - loss: 0.6343 - accuracy: 0.7871 - val_loss: 0.8580 - val_accuracy: 0.7100 - lr: 1.0000e-04 - 6s/epoch - 20ms/step
# Epoch 13/80
# 282/282 - 7s - loss: 0.5994 - accuracy: 0.7978 - val_loss: 0.8488 - val_accuracy: 0.7130 - lr: 1.0000e-04 - 7s/epoch - 26ms/step
# Epoch 14/80
# 282/282 - 7s - loss: 0.5642 - accuracy: 0.8070 - val_loss: 0.8774 - val_accuracy: 0.7220 - lr: 1.0000e-04 - 7s/epoch - 24ms/step
# Epoch 15/80
# 282/282 - 7s - loss: 0.5365 - accuracy: 0.8184 - val_loss: 0.8274 - val_accuracy: 0.7340 - lr: 1.0000e-04 - 7s/epoch - 24ms/step
# Epoch 16/80
# 282/282 - 7s - loss: 0.5127 - accuracy: 0.8256 - val_loss: 0.8254 - val_accuracy: 0.7270 - lr: 1.0000e-04 - 7s/epoch - 23ms/step
# Epoch 17/80
# 282/282 - 7s - loss: 0.4825 - accuracy: 0.8368 - val_loss: 0.7876 - val_accuracy: 0.7430 - lr: 1.0000e-04 - 7s/epoch - 23ms/step
# Epoch 18/80
# 282/282 - 6s - loss: 0.4490 - accuracy: 0.8492 - val_loss: 0.8245 - val_accuracy: 0.7350 - lr: 1.0000e-04 - 6s/epoch - 23ms/step
# Epoch 19/80
# 282/282 - 6s - loss: 0.4201 - accuracy: 0.8594 - val_loss: 0.8163 - val_accuracy: 0.7430 - lr: 1.0000e-04 - 6s/epoch - 23ms/step
# Epoch 20/80
# 282/282 - 6s - loss: 0.4011 - accuracy: 0.8667 - val_loss: 0.7961 - val_accuracy: 0.7550 - lr: 1.0000e-04 - 6s/epoch - 22ms/step
# Epoch 21/80
# 282/282 - 5s - loss: 0.3790 - accuracy: 0.8724 - val_loss: 0.8327 - val_accuracy: 0.7470 - lr: 1.0000e-04 - 5s/epoch - 19ms/step
# Epoch 22/80
# 282/282 - 6s - loss: 0.3583 - accuracy: 0.8816 - val_loss: 0.8431 - val_accuracy: 0.7460 - lr: 1.0000e-04 - 6s/epoch - 23ms/step
# Epoch 23/80
# 282/282 - 6s - loss: 0.3405 - accuracy: 0.8869 - val_loss: 0.8187 - val_accuracy: 0.7410 - lr: 1.0000e-04 - 6s/epoch - 23ms/step
# Epoch 24/80
# 282/282 - 6s - loss: 0.3204 - accuracy: 0.8904 - val_loss: 0.8376 - val_accuracy: 0.7440 - lr: 1.0000e-04 - 6s/epoch - 22ms/step
# Epoch 25/80
# 282/282 - 7s - loss: 0.3123 - accuracy: 0.8953 - val_loss: 0.7839 - val_accuracy: 0.7570 - lr: 1.0000e-04 - 7s/epoch - 23ms/step
# Epoch 26/80
# 282/282 - 6s - loss: 0.2685 - accuracy: 0.9113 - val_loss: 0.8082 - val_accuracy: 0.7600 - lr: 1.0000e-04 - 6s/epoch - 22ms/step
# Epoch 27/80
# 282/282 - 6s - loss: 0.3131 - accuracy: 0.8955 - val_loss: 0.7858 - val_accuracy: 0.7680 - lr: 1.0000e-04 - 6s/epoch - 22ms/step
# Epoch 28/80
# 282/282 - 7s - loss: 0.2742 - accuracy: 0.9095 - val_loss: 0.7497 - val_accuracy: 0.7850 - lr: 1.0000e-04 - 7s/epoch - 24ms/step
# Epoch 29/80
# 282/282 - 7s - loss: 0.2446 - accuracy: 0.9200 - val_loss: 0.7757 - val_accuracy: 0.7720 - lr: 1.0000e-04 - 7s/epoch - 24ms/step
# Epoch 30/80
# 282/282 - 6s - loss: 0.2098 - accuracy: 0.9357 - val_loss: 0.8342 - val_accuracy: 0.7820 - lr: 1.0000e-04 - 6s/epoch - 23ms/step
# Epoch 31/80
# 282/282 - 6s - loss: 0.2236 - accuracy: 0.9291 - val_loss: 0.8661 - val_accuracy: 0.7590 - lr: 1.0000e-04 - 6s/epoch - 22ms/step
# Epoch 32/80
# 282/282 - 5s - loss: 0.2221 - accuracy: 0.9300 - val_loss: 0.8309 - val_accuracy: 0.7720 - lr: 1.0000e-04 - 5s/epoch - 19ms/step
# Epoch 33/80
# 282/282 - 6s - loss: 0.2043 - accuracy: 0.9347 - val_loss: 0.8347 - val_accuracy: 0.7730 - lr: 1.0000e-04 - 6s/epoch - 20ms/step
# Epoch 34/80
# 282/282 - 5s - loss: 0.1476 - accuracy: 0.9608 - val_loss: 0.8002 - val_accuracy: 0.7830 - lr: 5.0000e-06 - 5s/epoch - 19ms/step
# Epoch 35/80
# 282/282 - 5s - loss: 0.1306 - accuracy: 0.9664 - val_loss: 0.7951 - val_accuracy: 0.7870 - lr: 5.0000e-06 - 5s/epoch - 19ms/step
# Epoch 36/80
# 282/282 - 6s - loss: 0.1241 - accuracy: 0.9687 - val_loss: 0.7957 - val_accuracy: 0.7890 - lr: 5.0000e-06 - 6s/epoch - 22ms/step
# Epoch 37/80
# 282/282 - 6s - loss: 0.1200 - accuracy: 0.9704 - val_loss: 0.8006 - val_accuracy: 0.7890 - lr: 5.0000e-06 - 6s/epoch - 22ms/step
# Epoch 38/80
# 282/282 - 6s - loss: 0.1164 - accuracy: 0.9705 - val_loss: 0.8024 - val_accuracy: 0.7870 - lr: 5.0000e-06 - 6s/epoch - 22ms/step
# Epoch 39/80
# 282/282 - 6s - loss: 0.1138 - accuracy: 0.9725 - val_loss: 0.8055 - val_accuracy: 0.7870 - lr: 5.0000e-06 - 6s/epoch - 22ms/step
# Epoch 40/80
# 282/282 - 6s - loss: 0.1112 - accuracy: 0.9730 - val_loss: 0.8083 - val_accuracy: 0.7890 - lr: 5.0000e-06 - 6s/epoch - 22ms/step
# Epoch 41/80
# 282/282 - 6s - loss: 0.1088 - accuracy: 0.9738 - val_loss: 0.8096 - val_accuracy: 0.7910 - lr: 5.0000e-06 - 6s/epoch - 22ms/step
# Epoch 42/80
# 282/282 - 6s - loss: 0.1065 - accuracy: 0.9749 - val_loss: 0.8086 - val_accuracy: 0.7930 - lr: 5.0000e-06 - 6s/epoch - 22ms/step
# Epoch 43/80
# 282/282 - 6s - loss: 0.1044 - accuracy: 0.9744 - val_loss: 0.8114 - val_accuracy: 0.7920 - lr: 5.0000e-06 - 6s/epoch - 22ms/step
# Epoch 44/80
# 282/282 - 6s - loss: 0.1023 - accuracy: 0.9757 - val_loss: 0.8090 - val_accuracy: 0.7930 - lr: 5.0000e-06 - 6s/epoch - 23ms/step
# Epoch 45/80
# 282/282 - 6s - loss: 0.1005 - accuracy: 0.9764 - val_loss: 0.8103 - val_accuracy: 0.7950 - lr: 5.0000e-06 - 6s/epoch - 22ms/step
# Epoch 46/80
# 282/282 - 6s - loss: 0.0984 - accuracy: 0.9761 - val_loss: 0.8149 - val_accuracy: 0.7930 - lr: 5.0000e-06 - 6s/epoch - 23ms/step
# Epoch 47/80
# 282/282 - 7s - loss: 0.0964 - accuracy: 0.9777 - val_loss: 0.8140 - val_accuracy: 0.7940 - lr: 5.0000e-06 - 7s/epoch - 26ms/step
# Epoch 48/80
# 282/282 - 7s - loss: 0.0947 - accuracy: 0.9785 - val_loss: 0.8202 - val_accuracy: 0.7920 - lr: 5.0000e-06 - 7s/epoch - 26ms/step
# Epoch 49/80
# 282/282 - 7s - loss: 0.0928 - accuracy: 0.9783 - val_loss: 0.8183 - val_accuracy: 0.7900 - lr: 5.0000e-06 - 7s/epoch - 24ms/step
# Epoch 50/80
# 282/282 - 7s - loss: 0.0913 - accuracy: 0.9783 - val_loss: 0.8224 - val_accuracy: 0.7950 - lr: 5.0000e-06 - 7s/epoch - 24ms/step
# Epoch 51/80
# 282/282 - 7s - loss: 0.0876 - accuracy: 0.9804 - val_loss: 0.8226 - val_accuracy: 0.7950 - lr: 2.5000e-07 - 7s/epoch - 26ms/step
# Epoch 52/80
# 282/282 - 7s - loss: 0.0875 - accuracy: 0.9807 - val_loss: 0.8227 - val_accuracy: 0.7940 - lr: 2.5000e-07 - 7s/epoch - 23ms/step
# Epoch 53/80
# 282/282 - 7s - loss: 0.0874 - accuracy: 0.9805 - val_loss: 0.8229 - val_accuracy: 0.7950 - lr: 2.5000e-07 - 7s/epoch - 24ms/step
# Epoch 54/80
# 282/282 - 6s - loss: 0.0872 - accuracy: 0.9807 - val_loss: 0.8230 - val_accuracy: 0.7940 - lr: 2.5000e-07 - 6s/epoch - 22ms/step
# Epoch 55/80
# 282/282 - 7s - loss: 0.0871 - accuracy: 0.9807 - val_loss: 0.8233 - val_accuracy: 0.7940 - lr: 2.5000e-07 - 7s/epoch - 24ms/step
# Epoch 56/80
# 282/282 - 7s - loss: 0.0869 - accuracy: 0.9807 - val_loss: 0.8233 - val_accuracy: 0.7940 - lr: 1.2500e-08 - 7s/epoch - 24ms/step
# Epoch 57/80
# 282/282 - 5s - loss: 0.0869 - accuracy: 0.9807 - val_loss: 0.8233 - val_accuracy: 0.7940 - lr: 1.2500e-08 - 5s/epoch - 19ms/step
# Epoch 58/80
# 282/282 - 5s - loss: 0.0869 - accuracy: 0.9807 - val_loss: 0.8233 - val_accuracy: 0.7940 - lr: 1.2500e-08 - 5s/epoch - 18ms/step
# Epoch 59/80
# 282/282 - 5s - loss: 0.0869 - accuracy: 0.9807 - val_loss: 0.8233 - val_accuracy: 0.7940 - lr: 1.2500e-08 - 5s/epoch - 18ms/step
# Epoch 60/80
# 282/282 - 5s - loss: 0.0869 - accuracy: 0.9807 - val_loss: 0.8233 - val_accuracy: 0.7940 - lr: 1.2500e-08 - 5s/epoch - 18ms/step
# Epoch 61/80
# 282/282 - 5s - loss: 0.0869 - accuracy: 0.9807 - val_loss: 0.8233 - val_accuracy: 0.7940 - lr: 6.2500e-10 - 5s/epoch - 18ms/step
# Epoch 62/80
# 282/282 - 6s - loss: 0.0869 - accuracy: 0.9807 - val_loss: 0.8233 - val_accuracy: 0.7940 - lr: 6.2500e-10 - 6s/epoch - 20ms/step
# Epoch 63/80
# 282/282 - 6s - loss: 0.0869 - accuracy: 0.9807 - val_loss: 0.8233 - val_accuracy: 0.7940 - lr: 6.2500e-10 - 6s/epoch - 22ms/step
# Epoch 64/80
# 282/282 - 6s - loss: 0.0869 - accuracy: 0.9807 - val_loss: 0.8233 - val_accuracy: 0.7940 - lr: 6.2500e-10 - 6s/epoch - 23ms/step
# Epoch 65/80
# 282/282 - 7s - loss: 0.0869 - accuracy: 0.9807 - val_loss: 0.8233 - val_accuracy: 0.7940 - lr: 6.2500e-10 - 7s/epoch - 25ms/step
# Epoch 66/80
# 282/282 - 7s - loss: 0.0869 - accuracy: 0.9807 - val_loss: 0.8233 - val_accuracy: 0.7940 - lr: 3.1250e-11 - 7s/epoch - 23ms/step
# Epoch 67/80
# 282/282 - 6s - loss: 0.0869 - accuracy: 0.9807 - val_loss: 0.8233 - val_accuracy: 0.7940 - lr: 3.1250e-11 - 6s/epoch - 23ms/step
# Epoch 68/80
# 282/282 - 7s - loss: 0.0869 - accuracy: 0.9807 - val_loss: 0.8233 - val_accuracy: 0.7940 - lr: 3.1250e-11 - 7s/epoch - 24ms/step
# Epoch 69/80
# 282/282 - 6s - loss: 0.0869 - accuracy: 0.9807 - val_loss: 0.8233 - val_accuracy: 0.7940 - lr: 3.1250e-11 - 6s/epoch - 23ms/step
# Epoch 70/80
# 282/282 - 6s - loss: 0.0869 - accuracy: 0.9807 - val_loss: 0.8233 - val_accuracy: 0.7940 - lr: 3.1250e-11 - 6s/epoch - 21ms/step
# Epoch 71/80
# 282/282 - 5s - loss: 0.0869 - accuracy: 0.9807 - val_loss: 0.8233 - val_accuracy: 0.7940 - lr: 1.5625e-12 - 5s/epoch - 19ms/step
# Epoch 72/80
# 282/282 - 6s - loss: 0.0869 - accuracy: 0.9807 - val_loss: 0.8233 - val_accuracy: 0.7940 - lr: 1.5625e-12 - 6s/epoch - 21ms/step
# Epoch 73/80
# 282/282 - 5s - loss: 0.0869 - accuracy: 0.9807 - val_loss: 0.8233 - val_accuracy: 0.7940 - lr: 1.5625e-12 - 5s/epoch - 19ms/step
# Epoch 74/80
# 282/282 - 5s - loss: 0.0869 - accuracy: 0.9807 - val_loss: 0.8233 - val_accuracy: 0.7940 - lr: 1.5625e-12 - 5s/epoch - 19ms/step
# Epoch 75/80
# 282/282 - 6s - loss: 0.0869 - accuracy: 0.9807 - val_loss: 0.8233 - val_accuracy: 0.7940 - lr: 1.5625e-12 - 6s/epoch - 20ms/step
# Epoch 76/80
# 282/282 - 5s - loss: 0.0869 - accuracy: 0.9807 - val_loss: 0.8233 - val_accuracy: 0.7940 - lr: 7.8125e-14 - 5s/epoch - 19ms/step
# Epoch 77/80
# 282/282 - 5s - loss: 0.0869 - accuracy: 0.9807 - val_loss: 0.8233 - val_accuracy: 0.7940 - lr: 7.8125e-14 - 5s/epoch - 19ms/step
# Epoch 78/80
# 282/282 - 6s - loss: 0.0869 - accuracy: 0.9807 - val_loss: 0.8233 - val_accuracy: 0.7940 - lr: 7.8125e-14 - 6s/epoch - 20ms/step
# Epoch 79/80
# 282/282 - 5s - loss: 0.0869 - accuracy: 0.9807 - val_loss: 0.8233 - val_accuracy: 0.7940 - lr: 7.8125e-14 - 5s/epoch - 18ms/step
# Epoch 80/80
# 282/282 - 5s - loss: 0.0869 - accuracy: 0.9807 - val_loss: 0.8233 - val_accuracy: 0.7940 - lr: 7.8125e-14 - 5s/epoch - 18ms/step

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(7,7)) #Setting plot dimensions

#Plotting training and test accuracy of model
plt.subplot(2,1,1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='lower right')

#Plotting training and test loss of model
plt.subplot(2,1,2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.suptitle('LSTM Classification',fontsize=30,y=1.03)
plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import classification_report
labelNames = ['pop','metal','disco','blues','reggae','classical','rock','hiphop','country','jazz']
predictions = model.predict(X_test, batch_size=32) #Use model to predict on the test data
# Out:
# 32/32 [==============================] - 1s 14ms/step

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
matrix = confusion_matrix(y_test, predictions.argmax(axis=1)) #Compute confusion matrix to evaluate the accuracy of a classification
sns.heatmap(matrix,annot=True,fmt='d',yticklabels=labelNames,xticklabels=labelNames) #Plot confusion matrix as a heatmap
plt.title('LSTM Classification');

# %%
88.2
# Out:
# 88.2
